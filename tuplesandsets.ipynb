# %%
empty_tuple = tuple()
len(empty_tuple)
# Out:
# 0

# %%
fruits = ('banana', 'orange', 'mango', 'lemon')
# syntax
tpl = ('item1', 'item2','item3')
len(fruits)
len(tpl)
# Out:
# 3

# %%
tpl[0]
# Out:
# 'item1'

# %%
'strawberry' in fruits
# Out:
# False

# %%
mix = fruits + tpl

# %%
len(mix)
# Out:
# 7

# %%
mix
# Out:
# ('banana', 'orange', 'mango', 'lemon', 'item1', 'item2', 'item3')

# %%
fruits[0:2]
# Out:
# ('banana', 'orange')

# %%
fruits[2:4]
# Out:
# ('mango', 'lemon')

# %%
del tpl
del fruits

# %%
#sets
empty_set = set()
fruits = {'banana', 'orange', 'mango', 'lemon'}
len(fruits)
# Out:
# 4

# %%
berries = {'blueberry','strawberry','rasberry'}

# %%
'mango' in fruits
# Out:
# True

# %%
berries.add('blackberry')

# %%
berries.len()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 berries.len()
#
# AttributeError: 'set' object has no attribute 'len'

# %%
len(berries)
# Out:
# 4

# %%
fruits.update(berries)

# %%
len(fruits)
# Out:
# 8

# %%
fruits
# Out:
# {'banana',
#  'blackberry',
#  'blueberry',
#  'lemon',
#  'mango',
#  'orange',
#  'rasberry',
#  'strawberry'}

# %%
lst = ['item1','item2','item1','item3']

# %%
lst
# Out:
# ['item1', 'item2', 'item1', 'item3']

# %%
itemset = set(lst)

# %%
itemset
# Out:
# {'item1', 'item2', 'item3'}

# %%
# syntax
st1 = {'item1', 'item2', 'item3', 'item4'}
st2 = {'item1', 'item2', 'item7', 'item8'}
st3 = st1.union(st2)

# %%
st3
# Out:
# {'item1', 'item2', 'item3', 'item4', 'item7', 'item8'}

# %%
print(st1.intersection(st2))
# Out:
# {'item2', 'item1'}

# %%
st1.issubset(st2)
# Out:
# False

# %%
st1.difference(st2)
# Out:
# {'item3', 'item4'}

# %%
st2.difference(st1)
# Out:
# {'item7', 'item8'}

# %%
st1.symmetric_difference(st2)
# Out:
# {'item3', 'item4', 'item7', 'item8'}

# %%
#Dictionnary
empty_dict = {} #dict()

# %%
len(empty_dict)
# Out:
# 0

# %%
person = {
    'first_name':'Asabeneh',
    'last_name':'Yetayeh',
    'age':250,
    'country':'Finland',
    'is_marred':True,
    'skills':['JavaScript', 'React', 'Node', 'MongoDB', 'Python'],
    'address':{
        'street':'Space street',
        'zipcode':'02210'
    }
    }

# %%
len(person)
# Out:
# 7

# %%
person['first_name']
# Out:
# 'Asabeneh'

# %%
person['skills'][0]
# Out:
# 'JavaScript'

# %%
person['skills'].append('html')

# %%
person
# Out:
# {'first_name': 'Asabeneh',
#  'last_name': 'Yetayeh',
#  'age': 250,
#  'country': 'Finland',
#  'is_marred': True,
#  'skills': ['JavaScript', 'React', 'Node', 'MongoDB', 'Python', 'html'],
#  'address': {'street': 'Space street', 'zipcode': '02210'}}

# %%
'address' in person
# Out:
# True

# %%
person.
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[52], line 1
# ----> 1 pop(person)
#
# NameError: name 'pop' is not defined

# %%
person.keys()
# Out:
# dict_keys(['first_name', 'last_name', 'age', 'country', 'is_marred', 'skills', 'address'])

# %%
person.values()
# Out:
# dict_values(['Asabeneh', 'Yetayeh', 250, 'Finland', True, ['JavaScript', 'React', 'Node', 'MongoDB', 'Python', 'html'], {'street': 'Space street', 'zipcode': '02210'}])

# %%
lst_dict = list(person.values())

# %%
lst_dict
# Out:
# ['Asabeneh',
#  'Yetayeh',
#  250,
#  'Finland',
#  True,
#  ['JavaScript', 'React', 'Node', 'MongoDB', 'Python', 'html'],
#  {'street': 'Space street', 'zipcode': '02210'}]

# %%
lst_dict.pop()
# Out:
# {'street': 'Space street', 'zipcode': '02210'}

# %%
lst_dict
# Out:
# ['Asabeneh',
#  'Yetayeh',
#  250,
#  'Finland',
#  True,
#  ['JavaScript', 'React', 'Node', 'MongoDB', 'Python', 'html']]

# %%
def greet(name):
    return "Hello, " + name
for _ in range(3):
    print(greet("Alice"))
# Out:
# Hello, Alice
# Hello, Alice
# Hello, Alice
