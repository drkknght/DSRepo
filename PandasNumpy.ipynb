# %%
# %pip install xlrd openpyxl
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting xlrd
#   Downloading xlrd-2.0.2-py2.py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: openpyxl in c:\programdata\anaconda3\lib\site-packages (3.1.5)
# Requirement already satisfied: et-xmlfile in c:\programdata\anaconda3\lib\site-packages (from openpyxl) (1.1.0)
# Downloading xlrd-2.0.2-py2.py3-none-any.whl (96 kB)
# Installing collected packages: xlrd
# Successfully installed xlrd-2.0.2
# Note: you may need to restart the kernel to use updated packages.

# %%
# Read data from CSV file

# csv_path = 'https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/LXjSAttmoxJfEG6il1Bqfw/Product-sales.csv'
# df = pd.read_csv(csv_path)

import pandas as pd

filename = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/LXjSAttmoxJfEG6il1Bqfw/Product-sales.csv"

async def download(url, filename):
#    response = await pyfetch(url)
    response = await pd.read_csv(filename)
    if response.status == 200:
        with open(filename, "wb") as f:
            f.write(await response.bytes())


#await download(filename, "Product-sales.csv")
df = pd.read_csv(filename)
df.dtypes
# Out:
# OrderID          int64
# Product         object
# Category        object
# Quantity         int64
# Price            int64
# Total            int64
# OrderDate       object
# CustomerCity    object
# dtype: object

# %%
df
# Out:
#    OrderID     Product     Category  Quantity  Price  Total   OrderDate  \
# 0        1      Laptop  Electronics         2    800   1600  2022-01-10
# 1        2  Smartphone  Electronics         3    600   1800  2022-02-15
# 2        3  Desk Chair    Furniture         5    150    750  2022-03-12
# 3        4    Notebook   Stationery        10      2     20  2022-04-05
# 4        5     Monitor  Electronics         1    300    300  2022-05-21
#
#   CustomerCity
# 0     New York
# 1  Los Angeles
# 2      Chicago
# 3      Houston
# 4        Miami

# %%
#Numpy
import numpy as np
a = np.array([0,1.1,2.1,3.1,4.1,5.1,6.1,7.2])
np.dot(a)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[48], line 4
#       2 import numpy as np
#       3 a = np.array([0,1.1,2.1,3.1,4.1,5.1,6.1,7.2])
# ----> 4 np.dot(a)
#
# TypeError: dot() missing 1 required positional argument: 'b'

# %%
type(a)
np.__version__
# Out:
# '1.26.4'

# %%
a.dtype
# Out:
# dtype('float64')

# %%
a[0]=100

# %%
a
# Out:
# array([100. ,   1.1,   2.1,   3.1,   4.1,   5.1,   6.1,   7.2])

# %%
b = a[2:5]

# %%
b
# Out:
# array([2.1, 3.1, 4.1])

# %%
a[1:5:3]
# Out:
# array([1.1, 4.1])

# %%
a[3:5] = 300, 400

# %%
a[2:]
# Out:
# array([  2.1, 300. , 400. ,   5.1,   6.1,   7.2])

# %%
a.mean()
# Out:
# 102.70000000000002

# %%
a.std()
# Out:
# 148.21536694958453

# %%
a.max()
# Out:
# 400.0

# %%
a.min()
# Out:
# 1.1

# %%
import numpy as np
a = [-1,1]
b = [1,1]
dotarr = np.dot(a,b)
t = np.dot(a.T,b)
t
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[61], line 5
#       3 b = [1,1]
#       4 dotarr = np.dot(a,b)
# ----> 5 t = np.dot(a.T,b)
#       6 t
#
# AttributeError: 'list' object has no attribute 'T'

# %%
anp = np.array(a)

# %%
anp.ndim
# Out:
# 2

# %%
anp.shape
# Out:
# (3, 3)

# %%
anp.cumsum(anp)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 anp.cumsum(anp)
#
# TypeError: only integer scalar arrays can be converted to a scalar index

# %%
anp.dtype()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 anp.dtype()
#
# TypeError: 'numpy.dtypes.Int32DType' object is not callable

# %%
anp.max()
# Out:
# 33

# %%
anp[0][0]
# Out:
# 11

# %%
anp[0:3,2]
# Out:
# array([13, 23, 33])

# %%
anp[0,0:3]
# Out:
# array([11, 12, 13])

# %%
z = 2 * anp

# %%
z
# Out:
# array([[22, 24, 26],
#        [42, 44, 46],
#        [62, 64, 66]])

# %%
zdot =np.dot(a,z)
zdot
# Out:
# array([1552, 1624, 1696])

# %%
np.sin(zdot)
# Out:
# array([[ 0.05320399,  0.20200227, -0.44397762],
#        [-0.27113792, -0.32185074, -0.37165598],
#        [ 0.47584185, -0.75703889,  0.93965388]])

# %%
z.T
# Out:
# array([[22, 42, 62],
#        [24, 44, 64],
#        [26, 46, 66]])

# %%
anp.reshape(2,3)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 anp.reshape(2,3)
#
# ValueError: cannot reshape array of size 9 into shape (2,3)

# %%
arr = np.array([1, 2, 3, 4, 5])
arr.reshape(2,3)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[33], line 2
#       1 arr = np.array([1, 2, 3, 4, 5])
# ----> 2 arr.reshape(2,3)
#
# ValueError: cannot reshape array of size 5 into shape (2,3)

# %%
np.sqrt(arr)
# Out:
# array([1.        , 1.41421356, 1.73205081, 2.        , 2.23606798])

# %%
df[["OrderID","Product"]]
# Out:
#    OrderID     Product
# 0        1      Laptop
# 1        2  Smartphone
# 2        3  Desk Chair
# 3        4    Notebook
# 4        5     Monitor

# %%
df.describe()
# Out:
#         OrderID   Quantity       Price       Total
# count  5.000000   5.000000    5.000000     5.00000
# mean   3.000000   4.200000  370.400000   894.00000
# std    1.581139   3.563706  326.543718   783.69637
# min    1.000000   1.000000    2.000000    20.00000
# 25%    2.000000   2.000000  150.000000   300.00000
# 50%    3.000000   3.000000  300.000000   750.00000
# 75%    4.000000   5.000000  600.000000  1600.00000
# max    5.000000  10.000000  800.000000  1800.00000

# %%
df.dropna()
# Out:
#    OrderID     Product     Category  Quantity  Price  Total   OrderDate  \
# 0        1      Laptop  Electronics         2    800   1600  2022-01-10
# 1        2  Smartphone  Electronics         3    600   1800  2022-02-15
# 2        3  Desk Chair    Furniture         5    150    750  2022-03-12
# 3        4    Notebook   Stationery        10      2     20  2022-04-05
# 4        5     Monitor  Electronics         1    300    300  2022-05-21
#
#   CustomerCity
# 0     New York
# 1  Los Angeles
# 2      Chicago
# 3      Houston
# 4        Miami

# %%
expdf = df[(df["Price"] > 500)]

# %%
expdf
# Out:
#    OrderID     Product     Category  Quantity  Price  Total   OrderDate  \
# 0        1      Laptop  Electronics         2    800   1600  2022-01-10
# 1        2  Smartphone  Electronics         3    600   1800  2022-02-15
#
#   CustomerCity
# 0     New York
# 1  Los Angeles

# %%
df["CustomerCity"].replace("Miami","Austin", inplace = True)
df
# Out:
# C:\Users\frank\AppData\Local\Temp\ipykernel_2320\986466751.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["CustomerCity"].replace("Miami","Austin", inplace = True)
#    OrderID     Product     Category  Quantity  Price  Total   OrderDate  \
# 0        1      Laptop  Electronics         2    800   1600  2022-01-10
# 1        2  Smartphone  Electronics         3    600   1800  2022-02-15
# 2        3  Desk Chair    Furniture         5    150    750  2022-03-12
# 3        4    Notebook   Stationery        10      2     20  2022-04-05
# 4        5     Monitor  Electronics         1    300    300  2022-05-21
#
#   CustomerCity
# 0     New York
# 1  Los Angeles
# 2      Chicago
# 3      Houston
# 4       Austin

# %%
df.tail(2)
# Out:
#    OrderID   Product     Category  Quantity  Price  Total   OrderDate  \
# 3        4  Notebook   Stationery        10      2     20  2022-04-05
# 4        5   Monitor  Electronics         1    300    300  2022-05-21
#
#   CustomerCity
# 3      Houston
# 4       Austin

# %%
df.iloc[0,0]
# Out:
# 1

# %%
X=np.array([[1,0],[0,1]]) 
Y=np.array([[2,2],[2,2]]) 
Z=np.dot(X,Y)

# %%
Z
# Out:
# array([[2, 2],
#        [2, 2]])
